# %%
import pandas as pd

# %%
sales=pd.read_csv("Sales.csv")
customers=pd.read_csv("Customers.csv", encoding='ISO-8859-1')
exchangerates=pd.read_csv("Exchange_Rates.csv")
products=pd.read_csv("Products.csv")
stores=pd.read_csv("Stores.csv")

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'], format='%m/%d/%Y')
sales['Delivery Date'] = pd.to_datetime(sales['Delivery Date'], format='%m/%d/%Y', errors='coerce')
sales['Currency Code'] = sales['Currency Code'].astype(str)

# %%
sales.fillna('Not Available', inplace=True)
sales
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# ...

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %%
stores.fillna(0,inplace=True)

# %%
stores.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %%
stores['Country']=stores['Country'].astype(str)
stores['State']=stores['State'].astype(str)
stores['Open Date']=pd.to_datetime(stores['Open Date'],format='%m/%d/%Y')

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
products['Unit Cost USD'] = products['Unit Cost USD'].replace('[\$,]', '', regex=True).astype(float)
products['Unit Price USD'] = products['Unit Price USD'].replace('[\$,]', '', regex=True).astype(float)

# %%
products.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customers.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
def convert_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%m/%d/%Y', errors='coerce').strftime('%m/%d/%Y')
    except ValueError:
        try:
            return pd.to_datetime(date_str, format='%d-%m-%Y', errors='coerce').strftime('%m/%d/%Y')
        except ValueError:
            return date_str 
customers['Birthday'] = customers['Birthday'].apply(convert_date)

# %%
customers['State Code'].fillna('Not Available', inplace=True)

# %%
customers['Birthday'] = pd.to_datetime(customers['Birthday'], format='%m/%d/%Y', errors='coerce')

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
exchangerates.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
exchangerates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchangerates['Date'] = pd.to_datetime(exchangerates['Date'], format='%m/%d/%Y', errors='coerce')

# %%
exchangerates
# Out:
#             Date Currency  Exchange
# 0     2015-01-01      USD    1.0000
# 1     2015-01-01      CAD    1.1583
# 2     2015-01-01      AUD    1.2214
# 3     2015-01-01      EUR    0.8237
# 4     2015-01-01      GBP    0.6415
# ...          ...      ...       ...
# 11210 2021-02-20      USD    1.0000
# 11211 2021-02-20      CAD    1.2610
# 11212 2021-02-20      AUD    1.2723
# 11213 2021-02-20      EUR    0.8238
# 11214 2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
sales
# Out:
#        Order Number  Line Item Order Date        Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01        Not Available       265598
# 1            366001          1 2016-01-01  2016-01-13 00:00:00      1269051
# 2            366001          2 2016-01-01  2016-01-13 00:00:00      1269051
# 3            366002          1 2016-01-01  2016-01-12 00:00:00       266019
# 4            366002          2 2016-01-01  2016-01-12 00:00:00       266019
# ...             ...        ...        ...                  ...          ...
# 62879       2243030          1 2021-02-20        Not Available      1216913
# 62880       2243031          1 2021-02-20  2021-02-24 00:00:00       511229
# 62881       2243032          1 2021-02-20  2021-02-23 00:00:00       331277
# 62882       2243032          2 2021-02-20  2021-02-23 00:00:00       331277
# 62883       2243032          3 2021-02-20  2021-02-23 00:00:00       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# ...

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
overall=sales

# %%
overall=pd.merge(overall,customers,on='CustomerKey',how='inner')

# %%
overall.dropna(inplace=True)

# %%
overall
# Out:
#        Order Number  Line Item Order Date  Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01  Not Available       265598
# 1            891000          1 2017-06-09  Not Available       265598
# 2            891000          2 2017-06-09  Not Available       265598
# 3            891000          3 2017-06-09  Not Available       265598
# 4            891000          4 2017-06-09  Not Available       265598
# ...             ...        ...        ...            ...          ...
# 62879       2242018          1 2021-02-19  Not Available        13365
# 62880       2243005          1 2021-02-20  Not Available       151326
# 62881       2243005          2 2021-02-20  Not Available       151326
# 62882       2243005          3 2021-02-20  Not Available       151326
# 62883       2243017          1 2021-02-20  Not Available      1237927
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender              Name  \
# ...

# %%
overall=pd.merge(overall,exchangerates,left_on=['Order Date','Currency Code'],right_on=['Date','Currency'],how='inner')

# %%
overall=pd.merge(overall,products,on='ProductKey',how='inner')

# %%
overall=pd.merge(overall,stores,on=['StoreKey','Country','State'],how='inner')

# %%
overall
# Out:
#       Order Number  Line Item Order Date  Delivery Date  CustomerKey  \
# 0          1603022          2 2019-05-22  Not Available      1416469
# 1           589006          2 2016-08-11  Not Available      1820936
# 2          1500010          1 2019-02-08  Not Available      1353710
# 3          1741003          1 2019-10-07  Not Available      1756245
# 4          1970008          3 2020-05-23  Not Available      1861020
# ...            ...        ...        ...            ...          ...
# 6176       1833003          2 2020-01-07  Not Available       666994
# 6177       1506028          1 2019-02-14  Not Available       686451
# 6178       1869004          1 2020-02-12  Not Available       616775
# 6179       1872009          2 2020-02-15  Not Available       696759
# 6180       1872009          1 2020-02-15  Not Available       696759
#
#       StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# 0           47        1304         3           USD  Female  ...
# ...

# %%
col=list(overall.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
    
overall.columns=col1

# %%
col=list(stores.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
    
stores.columns=col1

# %%
col1
# Out:
# ['storekey', 'country', 'state', 'square_meters', 'open_date']

# %%
overall.columns
# Out:
# Index(['order_number', 'line_item', 'order_date', 'delivery_date',
#        'customerkey', 'storekey', 'productkey', 'quantity', 'currency_code',
#        'gender', 'name', 'city', 'state_code', 'state', 'zip_code', 'country',
#        'continent', 'birthday', 'date', 'currency', 'exchange', 'product_name',
#        'brand', 'color', 'unit_cost_usd', 'unit_price_usd', 'subcategorykey',
#        'subcategory', 'categorykey', 'category', 'square_meters', 'open_date'],
#       dtype='object')

# %%
overall.isnull().sum()
# Out:
# order_number      0
# line_item         0
# order_date        0
# delivery_date     0
# customerkey       0
# storekey          0
# productkey        0
# quantity          0
# currency_code     0
# gender            0
# name              0
# city              0
# state_code        0
# state             0
# zip_code          0
# country           0
# continent         0
# birthday          0
# date              0
# currency          0
# exchange          0
# product_name      0
# brand             0
# color             0
# unit_cost_usd     0
# unit_price_usd    0
# subcategorykey    0
# subcategory       0
# categorykey       0
# category          0
# square_meters     0
# open_date         0
# dtype: int64

# %%
overall.dtypes
# Out:
# order_number               int64
# line_item                  int64
# order_date        datetime64[ns]
# delivery_date             object
# customerkey                int64
# storekey                   int64
# productkey                 int64
# quantity                   int64
# currency_code             object
# gender                    object
# name                      object
# city                      object
# state_code                object
# state                     object
# zip_code                  object
# country                   object
# continent                 object
# birthday          datetime64[ns]
# date              datetime64[ns]
# currency                  object
# exchange                 float64
# product_name              object
# brand                     object
# color                     object
# unit_cost_usd            float64
# unit_price_usd           float64
# subcategorykey             int64
# subcategory               object
# ...

# %%
overall[['order_date','date','currency_code','currency','customerkey']]
# Out:
#      order_date       date currency_code currency  customerkey
# 0    2019-05-22 2019-05-22           USD      USD      1416469
# 1    2016-08-11 2016-08-11           USD      USD      1820936
# 2    2019-02-08 2019-02-08           USD      USD      1353710
# 3    2019-10-07 2019-10-07           USD      USD      1756245
# 4    2020-05-23 2020-05-23           USD      USD      1861020
# ...         ...        ...           ...      ...          ...
# 6176 2020-01-07 2020-01-07           EUR      EUR       666994
# 6177 2019-02-14 2019-02-14           EUR      EUR       686451
# 6178 2020-02-12 2020-02-12           EUR      EUR       616775
# 6179 2020-02-15 2020-02-15           EUR      EUR       696759
# 6180 2020-02-15 2020-02-15           EUR      EUR       696759
#
# [6181 rows x 5 columns]

# %%
overall.to_csv('overall.csv')

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
  
#engine_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
engine_string='sqlite:///./db1.db'
engine = create_engine(engine_string)
 
table_name = "overall"
overall.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "customers"
customers.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "products"
products.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "exchangerates"
exchangerates.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "stores"
stores.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")
# Out:
# successfully imported overall to sql
# successfully imported customers to sql
# successfully imported products to sql
# successfully imported exchangerates to sql
# successfully imported stores to sql

# %% [markdown]
# # STORE ANALYSIS

# %%
#Size Bucket vs Total Sales
query = """
    SELECT
        CASE
            WHEN square_meters < 250 THEN '<250'
            WHEN square_meters BETWEEN 250 AND 500 THEN '250 to 500'
            WHEN square_meters BETWEEN 501 AND 750 THEN '500 to 750'
            WHEN square_meters BETWEEN 751 AND 1000 THEN '750 to 1000'
            WHEN square_meters BETWEEN 1001 AND 1250 THEN '1000 to 1250'
            WHEN square_meters BETWEEN 1251 AND 1500 THEN '1250 to 1500'
            WHEN square_meters BETWEEN 1501 AND 1750 THEN '1500 to 1750'
            WHEN square_meters BETWEEN 1751 AND 2000 THEN '1750 to 2000'
            WHEN square_meters > 2000 THEN '> 2000'
        END AS size_bucket,
        ROUND(SUM(unit_price_usd * quantity),2) AS total_sales
    FROM overall
    GROUP BY size_bucket
    ORDER BY
        CASE
            WHEN size_bucket = '<250' THEN 1
            WHEN size_bucket = '250 to 500' THEN 2
            WHEN size_bucket = '500 to 750' THEN 3
            WHEN size_bucket = '750 to 1000' THEN 4
            WHEN size_bucket = '1000 to 1250' THEN 5
            WHEN size_bucket = '1250 to 1500' THEN 6
            WHEN size_bucket = '1500 to 1750' THEN 7
            WHEN size_bucket = '1750 to 2000' THEN 8
            WHEN size_bucket = '> 2000' THEN 9
        END;
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#     size_bucket  total_sales
# 0          <250      8748.39
# 1    250 to 500     38289.76
# 2    500 to 750     50976.58
# 3   750 to 1000    143789.53
# 4  1000 to 1250    314757.44
# 5  1250 to 1500    606031.11
# 6  1500 to 1750    378807.25
# 7  1750 to 2000   4052086.45
# 8        > 2000     11374.73

# %%
#Store Age Bucket vs Total Sales
query = """
    SELECT
        CASE
            WHEN strftime('%Y', 'now') - strftime('%Y', open_date) <= 5 THEN '<=5'
            WHEN strftime('%Y', 'now') - strftime('%Y', open_date) BETWEEN 6 AND  10 THEN '5 to 10'
            WHEN strftime('%Y', 'now') - strftime('%Y', open_date) BETWEEN 11 AND 15 THEN '10 to 15'
            WHEN strftime('%Y', 'now') - strftime('%Y', open_date) BETWEEN 16 AND 20 THEN '15 to 20'
        END AS store_age_bucket,
        ROUND(SUM(unit_price_usd * quantity), 2) AS total_sales
    FROM overall
    GROUP BY store_age_bucket
    ORDER BY store_age_bucket
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#   store_age_bucket  total_sales
# 0         10 to 15   2964483.93
# 1         15 to 20   1137753.94
# 2          5 to 10   1502623.37

# %%
#Storekey vs Country vs Continent vs State    
query = """
    SELECT
      storekey,Country,Continent,State,
      ROUND(SUM((unit_price_usd)*quantity),2) AS total_revenue_USD
    FROM
      overall
    GROUP BY
      storekey,Country,Continent,State
    ORDER BY total_revenue_USD DESC
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#     storekey        country      continent                         state  \
# 0          5      Australia      Australia                      Victoria
# 1         61  United States  North America                South Carolina
# 2         45  United States  North America                   Connecticut
# 3         44  United States  North America                      Arkansas
# 4         50  United States  North America                        Kansas
# 5         55  United States  North America                        Nevada
# 6         59  United States  North America                        Oregon
# 7          6      Australia      Australia             Western Australia
# 8         54  United States  North America                      Nebraska
# 9         22        Germany         Europe           Freistaat Thüringen
# 10        49  United States  North America                          Iowa
# 11        65  United States  North America                 West Virginia
# ...

# %% [markdown]
# # SALES ANALYSIS

# %%
#sales analysis
query = """
    SELECT
      strftime('%m', order_date) AS month,
      ROUND(SUM((unit_price_usd)*quantity),2) AS total_revenue_USD
    FROM
      overall
    GROUP BY
      strftime('%m', order_date)
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#    month  total_revenue_USD
# 0     01          715612.63
# 1     02          707366.44
# 2     03          217266.32
# 3     04           66286.87
# 4     05          451108.03
# 5     06          446853.72
# 6     07          420813.35
# 7     08          383471.54
# 8     09          576509.54
# 9     10          415368.98
# 10    11          472039.41
# 11    12          732164.41

# %%
#Sales by Top Product Performance
query = """
    SELECT
      product_name,
      SUM(quantity) AS total_quantity
    FROM
       overall
    GROUP BY
      product_name
    ORDER BY total_quantity DESC
    LIMIT 10
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                                      product_name  total_quantity
# 0      Adventure Works Desktop PC1.60 ED160 Black              83
# 1                  WWI Desktop PC1.80 E1800 White              81
# 2                  WWI Desktop PC2.33 X2330 Black              73
# 3                  WWI Desktop PC2.30 M2300 Black              70
# 4                  WWI Desktop PC1.80 E1801 Brown              70
# 5                  WWI Desktop PC2.33 X2330 Brown              61
# 6                Contoso DVD Recorder L210 Silver              61
# 7                   WWI Desktop PC3.0 M0300 Black              60
# 8        SV DVD 9-Inch Player Portable M300 Black              60
# 9  Contoso DVD 7-Inch Player Portable E200 Silver              60

# %%
#Sales by Revenue Performance
query = """
    SELECT
      product_name,
      ROUND(SUM((unit_price_usd)*quantity),2) AS total_revenue_USD
    FROM
      overall
    GROUP BY
      product_name
    ORDER BY total_revenue_USD DESC
    LIMIT 10
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                                   product_name  total_revenue_USD
# 0               WWI Desktop PC2.33 X2330 Black           67087.00
# 1               WWI Desktop PC2.33 X2330 Brown           56059.00
# 2      Adventure Works 52" LCD HDTV X590 Black           52199.82
# 3  Adventure Works Desktop PC2.33 XD233 Silver           49419.00
# 4  Fabrikam Refrigerator 24.7CuFt X9800 Silver           47999.85
# 5   Adventure Works Desktop PC2.33 XD233 White           47481.00
# 6   Adventure Works Desktop PC2.33 XD233 Black           45543.00
# 7               WWI Desktop PC2.33 X2330 White           40436.00
# 8               WWI Desktop PC2.30 M2300 Black           39130.00
# 9     Adventure Works 52" LCD HDTV X790W Brown           38212.80

# %%
#Sales by Stores
query = """
    SELECT
      storekey,
      ROUND(SUM((unit_price_usd)*quantity),2) AS total_revenue_USD
    FROM
      overall
    GROUP BY
      storekey
    ORDER BY total_revenue_USD DESC
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#     storekey  total_revenue_USD
# 0          5          615067.94
# 1         61          360061.35
# 2         45          336819.75
# 3         44          329136.00
# 4         50          306740.75
# 5         55          295674.91
# 6         59          288211.36
# 7          6          241553.43
# 8         54          225052.43
# 9         22          206160.44
# 10        49          204976.86
# 11        65          145123.29
# 12        63          137755.11
# 13        64          131545.53
# 14        24          130467.47
# 15        57          126857.40
# 16        27          124385.47
# 17        51          111854.13
# 18        48          106235.28
# 19         4          104899.89
# 20        47          103711.05
# 21        66           97248.37
# 22        33           89140.96
# 23        62           89057.59
# 24        19           88239.16
# 25        23           79370.15
# 26        43           79260.13
# 27        56           70890.19
# ...

# %% [markdown]
# # PRODUCT ANALYSIS

# %%
#category and subcategory analysis
query = """
    SELECT
        category, subcategory,
        ROUND(SUM(unit_price_usd * quantity),2) AS total_sales
    FROM overall
    GROUP BY category, subcategory
    ORDER BY total_sales DESC
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                          category                       subcategory  \
# 0                       Computers                          Desktops
# 1                    TV and Video                       Televisions
# 2                       Computers              Projectors & Screens
# 3   Music, Movies and Audio Books                         Movie DVD
# 4                 Home Appliances                     Refrigerators
# 5                       Computers                           Laptops
# 6                 Home Appliances                     Water Heaters
# 7          Cameras and camcorders                        Camcorders
# 8                     Cell phones               Touch Screen Phones
# 9                     Cell phones               Smart phones & PDAs
# 10         Cameras and camcorders               Digital SLR Cameras
# 11                      Computers                          Monitors
# 12                Home Appliances                   Coffee Machines
# ...

# %%
#product popularity(top 10 most popular)
query = """
    SELECT
        product_name, SUM(quantity) AS Quantity
    FROM overall
    GROUP BY product_name
    ORDER BY Quantity DESC
    LIMIT 10
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                                      product_name  Quantity
# 0      Adventure Works Desktop PC1.60 ED160 Black        83
# 1                  WWI Desktop PC1.80 E1800 White        81
# 2                  WWI Desktop PC2.33 X2330 Black        73
# 3                  WWI Desktop PC2.30 M2300 Black        70
# 4                  WWI Desktop PC1.80 E1801 Brown        70
# 5                  WWI Desktop PC2.33 X2330 Brown        61
# 6                Contoso DVD Recorder L210 Silver        61
# 7                   WWI Desktop PC3.0 M0300 Black        60
# 8        SV DVD 9-Inch Player Portable M300 Black        60
# 9  Contoso DVD 7-Inch Player Portable E200 Silver        60

# %%
#product popularity(top 10 least popular)
query = """
    SELECT
        product_name, SUM(quantity) AS Quantity
    FROM overall
    GROUP BY product_name
    ORDER BY Quantity ASC
    LIMIT 10
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                                        product_name  Quantity
# 0        A. Datum Advanced Digital Camera M300 Grey         1
# 1          A. Datum Bridge Digital Camera M300 Pink         1
# 2         A. Datum Compact Digital Camera M200 Pink         1
# 3        A. Datum Consumer Digital Camera E100 Pink         1
# 4       A. Datum Consumer Digital Camera M300 Green         1
# 5    A. Datum Point Shoot Digital Camera M500 Green         1
# 6     A. Datum Point Shoot Digital Camera M500 Pink         1
# 7  A. Datum Point n' Shoot Digital Camera M500 Grey         1
# 8                 A. Datum SLR Camera 35" M358 Grey         1
# 9               A. Datum SLR Camera 35" M358 Orange         1

# %%
#profitablity analysis
query = """
    SELECT
        product_name,
        ROUND(SUM((unit_price_usd-unit_cost_usd)*quantity),2) AS Profit_Margin
    FROM overall
    GROUP BY product_name
    ORDER BY Profit_Margin DESC
    LIMIT 10
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#                                   product_name  Profit_Margin
# 0               WWI Desktop PC2.33 X2330 Black       44859.96
# 1               WWI Desktop PC2.33 X2330 Brown       37485.72
# 2      Adventure Works 52" LCD HDTV X590 Black       34905.06
# 3  Adventure Works Desktop PC2.33 XD233 Silver       33045.45
# 4  Fabrikam Refrigerator 24.7CuFt X9800 Silver       32096.55
# 5   Adventure Works Desktop PC2.33 XD233 White       31749.55
# 6   Adventure Works Desktop PC2.33 XD233 Black       30453.65
# 7               WWI Desktop PC2.33 X2330 White       27038.88
# 8     Adventure Works 52" LCD HDTV X790W Brown       25552.08
# 9     Adventure Works 52" LCD HDTV X790W Black       25552.08

# %% [markdown]
# # CUSTOMER ANALYSIS

# %%
#Gender count
query = """
    SELECT gender, COUNT(*) AS Count_gender
    FROM customers
    GROUP BY gender
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#    Gender  Count_gender
# 0  Female          7518
# 1    Male          7748

# %%
#Age Bucketing
query = """
    SELECT
        age_bucket,
        COUNT(*) AS count
    FROM (
        SELECT
            *,
            CASE
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) <= 18 THEN '<=18'
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) BETWEEN 18 AND 25 THEN '18-25'
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) BETWEEN 25 AND 35 THEN '25-35'
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) BETWEEN 35 AND 45 THEN '35-45'
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) BETWEEN 45 AND 55 THEN '45-55'
                WHEN strftime('%Y', order_date) - strftime('%Y', birthday) BETWEEN 55 AND 65 THEN '55-65'
                ELSE '>65'
            END AS age_bucket
        FROM overall
    ) AS age_groups
    GROUP BY age_bucket
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#   age_bucket  count
# 0      18-25    636
# 1      25-35    994
# 2      35-45    820
# 3      45-55    993
# 4      55-65    956
# 5       <=18    185
# 6        >65   1597

# %%
#country wise customer count
query = """
    SELECT 
        continent, country, state, city, 
        COUNT(CustomerKey) AS customer_count
    FROM 
        CUSTOMERS
    GROUP BY 
        continent, country, state, city
    ORDER BY 
        customer_count DESC
"""
results = pd.read_sql_query(query, engine)
print(results)
# Out:
#           Continent        Country       State          City  customer_count
# 0     North America         Canada     Ontario       Toronto             203
# 1     North America  United States    New York      New York             130
# 2     North America  United States  California   Los Angeles             119
# 3     North America         Canada      Quebec      Montreal              97
# 4     North America  United States    Illinois       Chicago              90
# ...             ...            ...         ...           ...             ...
# 8852  North America  United States     Wyoming       Jackson               1
# 8853  North America  United States     Wyoming        Lovell               1
# 8854  North America  United States     Wyoming      Riverton               1
# 8855  North America  United States     Wyoming  Rock Springs               1
# 8856  North America  United States     Wyoming     Ten Sleep               1
#
# [8857 rows x 5 columns]
